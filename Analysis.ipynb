# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
#!pip install scipy

# %%
housing = pd.read_excel('clean_housing.xlsx')
education = pd.read_excel('clean_education.xlsx')

# %%
#housing.columns
grouped_housing = housing.groupby(['region_name']).mean(numeric_only=True)
grouped_education = education.groupby('region_name').mean(numeric_only = True)
grouped_education
grouped_housing
# Out:
#                                Unnamed: 0  ind_id    percent  geotypevalue  \
# region_name
# Bay Area                    335703.920489   106.0  18.696276  39723.208716
# Butte                       215586.972973   106.0  18.358014  36896.722973
# Central/Southeast Sierra    256808.641304   106.0  16.983391  37379.559783
# Monterey Bay                351047.526154   106.0  20.007936  39463.824615
# North Coast                 245754.074468   106.0  19.637816  34588.454787
# Northeast Sierra            352280.132468   106.0  18.869800  38286.280519
# Northern Sacramento Valley  340043.358621   106.0  19.057349  38313.641379
# Sacramento Area             440209.442539   106.0  17.895334  40163.634648
# San Diego                   470079.517460   106.0  21.620399  38848.092063
# San Joaquin Valley          331950.977310   106.0  17.031642  42299.918152
# San Luis Obispo             464336.447761   106.0  17.020392  38668.694030
# Santa Barbara               465511.083969   106.0  17.733070  46251.832061
# Shasta                      455930.377778   106.0  14.436083  36687.322222
# Southern California         364651.286100   106.0  20.568798  42553.075574
#
#                             region_code
# region_name
# Bay Area                            1.0
# Butte                               2.0
# Central/Southeast Sierra            3.0
# Monterey Bay                        4.0
# North Coast                         5.0
# Northeast Sierra                    6.0
# Northern Sacramento Valley          7.0
# Sacramento Area                     8.0
# San Diego                           9.0
# San Joaquin Valley                 10.0
# San Luis Obispo                    11.0
# Santa Barbara                      12.0
# Shasta                             13.0
# Southern California                14.0

# %%
grouped_housing['percent'] = (grouped_housing['percent'] / 100)
grouped_education['estimate'] = (grouped_education['estimate'] / 100)
#print(grouped_education)
#print(grouped_housing)

# %%
grouped_housing['percent']
table = np.array([grouped_housing['percent'], grouped_education['estimate']])
print(table)

stat, pval, degrees, freq_array = stats.chi2_contingency(table)
#stat, pval, degrees, freq_array
stats.chi2_contingency(table)
# Out:
# [[0.18696276 0.18358014 0.16983391 0.20007936 0.19637816 0.188698
#   0.19057349 0.17895334 0.21620399 0.17031642 0.17020392 0.1773307
#   0.14436083 0.20568798]
#  [0.41161795 0.21531943 0.21814115 0.28898325 0.21423629 0.20796532
#   0.13022114 0.279517   0.31777172 0.14867877 0.30294865 0.31193394
#   0.20144705 0.27681319]]
# Chi2ContingencyResult(statistic=0.115151754549696, pvalue=0.999999999995556, dof=13, expected_freq=array([[0.25289082, 0.16852872, 0.16391329, 0.20662117, 0.17347807,
#         0.16758394, 0.13553063, 0.19369642, 0.22559624, 0.13477039,
#         0.19989943, 0.20670652, 0.14609832, 0.20384906],
#        [0.34568989, 0.23037085, 0.22406177, 0.28244144, 0.23713638,
#         0.22907938, 0.18526401, 0.26477392, 0.30837947, 0.1842248 ,
#         0.27325314, 0.28255812, 0.19970955, 0.27865211]]))
